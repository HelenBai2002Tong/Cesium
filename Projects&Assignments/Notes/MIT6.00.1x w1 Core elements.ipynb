# %% [markdown]
# ## Video:Bindings
# something can't be the name for varibles-keyword-different color
#
# reassign a name
#
# - x,y=y,x
#
#
# - temp=x
#
#   x=y
#
#   y=temp
#
# ## Video:Strings
#
# strings: double quotation marks or single quotes
#
# - concatenation
# - successive concatenation
# - length
# - indexing
# - slicing
#
# ## Video:Input/Output
#
# Output:(console)
# - print
#     - ,- with space
#
# Input:
# - input- a string
#   - if needs a number, need to cast it(eval, int,float)
#
# ## Video:IDEs
#
# painful to type things into shell
#
# what does it contain
#
# - text editor
# - Shell
# - Integrated debugger
#
# ## Video:Control Flow
#
# if, else, elif-branch-just once
#
# control flow
# - while loops
#   - unbounded
#   - end early
#   - can use a counter but must initial(counter but mush initiallead)
#   - may not be able to rewrite
#
# - for loops
#   - know the number
#   - end early
#   - counter
#   - can rewrite
#
# - stop
#   - break
#   - continue
#
# ## Video:Iteration
#
# use the code several times
#
# properties
# - set an iteration value outside the loop
# - test variable to determine when done
# - change the variable in the loop
#
# ## Video:Guess and Check
#
# infinite number to try
#
# using a loop to generate guess-declarative knowledge
#
# decrementing function
#
# error
# - don't initialize the variable
#
# check!
