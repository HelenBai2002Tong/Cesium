# %% [markdown]
# ## Chapter 1
#
# What do computer do- perform calculations and remenber the results
# computational thinking-
# - declarative knowledge- statements of facts
# - imperative knowledge- how to(√）
#   - algorithm: describe a computation
#
# - fixed program computers
# - stored-program computers
#    - interpreter: execute legal instructions
#    - flow of control: what to execute
#    - programming language
#    - not all programs can be compute- halting problem
#
# no best language
#
# literals, infix operators
#
# error
# - syntax
# - static semantics
# - semantics
#
# ## Chapter 2
#
# - low-level vs high-level
# - general vs tanged to an application domain
# - interpreted vs compiles
#
# ### 2.1
#
# command-statement of what to do
#
# #### 2.1.1
# Object: type-decide what can do
# scalar:
# - int
# - float
# - bool
# - Nonetype
#
# expressions - combined objects and operators
#
# #### 2.1.2 Variables and Assignment
# variables- associate name with objects
#
# for easily read- add comments
#
# x,y=y,x
#
# #### 2.1.3 IDLE
# - a text editor
# - a shell
# - an integrated debugger
#
# ### 2.2
#
# straight-line programs
#
# branching programs
# - conditional
#   - a text
#   - a block of code - if True
#   - an optional block of code - if False
#
# indentation!
#
# A program for which the maximum running time is bounded by the length of the
#
# program is said to run in constant time.
#
# ### 2.3
#
# "+"--different meanings depends on the type of objects
#
# string:
# - length
# - slice
# - index
#
# ### 2.3.1 input
# type is string- type casts
#
# ### 2.4
# iteration-looping
#
# ## Chapter 3
#
# ### 3.1
# Guess and Check
# - Exhaustive Enumeration
#    - computer is fast
#
# ### 3.2
# for loops-range
#
# ### 3.3
#
# approximation-close enough
#
# bisection
# - a way to find the answer
# - less steps
#
# ### 3.4
#
# floats
# - represented by significant digits & exponent
# - not so precise
#    - don't use == to compare two float
#
# ### 3.5
# Newton-Raphson- a way to find real roots for polynomial
#
# **successive approximation**- based on the current guess to find the next guess
