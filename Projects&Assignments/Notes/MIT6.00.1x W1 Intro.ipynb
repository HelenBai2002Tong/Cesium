# %% [markdown]
# ## Video:Introduction
# How can I make the computer work for me - computational thinking
#
# data structures
#
# iteration & recursion
#
# algorithms-complexity
#
#
# what do computers do- perform calculations really fastly and remember things
#
# Although fast and large storage -we still need to think carefully
#
# ## Video:Knowledge
#
# declarative knowledge- statement of fact
#
# **imperative knowledge**- "how to"(what we want)
#
# ## Video:Machines
#
# fixed program computer
#
# calculate a specific calculation
#
# - calculator
#
# stored program computer
#
# load in to it the instructions
#
# we need a interpreter
#
#
# what's inside the machine
#
# memory
#
# Arithmetic logic unit(ALU)(do primitive ops) &control unit(program counter-tell what to do next)
#
# input&output
#
#
#
# basic primitives
#
# six operations-move left, move right, scan, read, write&do nothing
#
# you can compute anything computable
#
# **abstract**
#
#
#
# whatever the programming language is, things computable are computable-**Turing complete**
#
#
# ## Video: Languages
#
# expressions:
#
# - more complex but legal combinations of primitives that the programming language will recognize
#
# - associated with the value
#
# programming language
#
# - a set of primitives
#
# syntax: legal
#
# static senmatics: meaning
#
# senmatics: assign a meaning to a legal sentence
#
#
# ## Video:Types
#
# a program-sequence of definitions and commands
#
# commands-instruct interpreter to do something
#
# objects
#
# - type- tell the program whether it can act on it or not
#
# scalar objects in Python
#
# - 1) Int
#
# - 2) Float
#
# - 3) Bool
#
# - 4) Nonetype
#
# cast-convert the type(int,float)
#
# no out: no value return
#
# syntax: <object><operater><object>
#
#
# ## Video:Variables
#
# assign a value to a varible name: =
#
# value stored in computer memory
#
# why give name?
#
# - reuse
#
# - easier to read
#
# - easier to change
#
# adding 1 to something--incrementing
#
# a=a+1--a+=1
#
# ## Video:Operators and Branching
#
# comparision
#
# "=="
#
# logic operators
#
# **branching**
#
# make choice and do different things
#
# each statement gets executed once
#
# run in constant time
#
# - conditional
#
#     - if else elif
